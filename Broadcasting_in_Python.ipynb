# %% [markdown]
# <a href="https://colab.research.google.com/github/Neha609/Python-Projects/blob/master/Broadcasting_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The term **broadcasting** refers to how numpy treats arrays with different Dimension during arithmetic operations which lead to certain constraints, the smaller array is **broadcast** across the larger array so that they have compatible shapes.

# %% [markdown]
# **Calculate % of calories from Carb, Protein, Fat.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

A = np.array([[56.0,0.0,4.4,68.0],
             [1.2,104.0,52.0,8.0],
             [1.8,135.0,99.0,0.9]])

print(A)
# Out:
# [[ 56.    0.    4.4  68. ]
#  [  1.2 104.   52.    8. ]
#  [  1.8 135.   99.    0.9]]

# %%
cal = A.sum(axis=0)
print(cal)
# Out:
# [ 59.  239.  155.4  76.9]

# %%
percentage = A/cal.reshape(1,4)
print(percentage)
# Out:
# [[0.94915254 0.         0.02831403 0.88426528]
#  [0.02033898 0.43514644 0.33462033 0.10403121]
#  [0.03050847 0.56485356 0.63706564 0.01170351]]

# %% [markdown]
# **Another example of Broadcasting is :**
#
# ![image.png](data:image/png;base64,...)
